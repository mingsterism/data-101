# %%
# https://towardsdatascience.com/a-beginners-guide-to-xgboost-87f5d4c30ed7
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

from datetime import datetime
pd.set_option('display.max_columns', None)

# %%
melb = pd.read_csv("./melb_data.csv")

melb.dropna(how='any', inplace=True)
melb = melb.drop(columns=['Address'])
melb.Regionname.unique()
# Out:
# array(['Northern Metropolitan', 'Western Metropolitan',
#        'Southern Metropolitan', 'Eastern Metropolitan',
#        'South-Eastern Metropolitan', 'Northern Victoria',
#        'Eastern Victoria', 'Western Victoria'], dtype=object)

# %%
melb.head()
# Out:
#        Suburb  Rooms Type      Price Method SellerG       Date  Distance  \
# 1  Abbotsford      2    h  1035000.0      S  Biggin  4/02/2016       2.5
# 2  Abbotsford      3    h  1465000.0     SP  Biggin  4/03/2017       2.5
# 4  Abbotsford      4    h  1600000.0     VB  Nelson  4/06/2016       2.5
# 6  Abbotsford      3    h  1876000.0      S  Nelson  7/05/2016       2.5
# 7  Abbotsford      2    h  1636000.0      S  Nelson  8/10/2016       2.5
#
#    Postcode  Bedroom2  Bathroom  Car  Landsize  BuildingArea  YearBuilt  \
# 1    3067.0       2.0       1.0  0.0     156.0          79.0     1900.0
# 2    3067.0       3.0       2.0  0.0     134.0         150.0     1900.0
# 4    3067.0       3.0       1.0  2.0     120.0         142.0     2014.0
# 6    3067.0       4.0       2.0  0.0     245.0         210.0     1910.0
# 7    3067.0       2.0       1.0  2.0     256.0         107.0     1890.0
#
#   CouncilArea  Lattitude  Longtitude             Regionname  Propertycount
# ...

# %%
melb.describe()
# Out:
#              Rooms         Price     Distance     Postcode     Bedroom2  \
# count  6196.000000  6.196000e+03  6196.000000  6196.000000  6196.000000
# mean      2.931407  1.068828e+06     9.751097  3101.947708     2.902034
# std       0.971079  6.751564e+05     5.612065    86.421604     0.970055
# min       1.000000  1.310000e+05     0.000000  3000.000000     0.000000
# 25%       2.000000  6.200000e+05     5.900000  3044.000000     2.000000
# 50%       3.000000  8.800000e+05     9.000000  3081.000000     3.000000
# 75%       4.000000  1.325000e+06    12.400000  3147.000000     3.000000
# max       8.000000  9.000000e+06    47.400000  3977.000000     9.000000
#
#           Bathroom          Car      Landsize  BuildingArea    YearBuilt  \
# count  6196.000000  6196.000000   6196.000000   6196.000000  6196.000000
# mean      1.576340     1.573596    471.006940    141.568645  1964.081988
# std       0.711362     0.929947    897.449881     90.834824    38.105673
# ...

# %%
# parse dates into year, month, day
year = lambda x: datetime.strptime(x, "%d/%m/%Y" ).year
weekday = lambda x: datetime.strptime(x, "%d/%m/%Y" ).weekday()
month = lambda x: datetime.strptime(x, "%d/%m/%Y" ).month

melb['Year'] = melb['Date'].map(year)
melb['Day'] = melb['Date'].map(weekday)
melb['Month'] = melb['Date'].map(month)
melb = melb.drop(columns=['Date'])
melb.head()
# Out:
#        Suburb  Rooms Type      Price Method SellerG  Distance  Postcode  \
# 1  Abbotsford      2    h  1035000.0      S  Biggin       2.5    3067.0
# 2  Abbotsford      3    h  1465000.0     SP  Biggin       2.5    3067.0
# 4  Abbotsford      4    h  1600000.0     VB  Nelson       2.5    3067.0
# 6  Abbotsford      3    h  1876000.0      S  Nelson       2.5    3067.0
# 7  Abbotsford      2    h  1636000.0      S  Nelson       2.5    3067.0
#
#    Bedroom2  Bathroom  Car  Landsize  BuildingArea  YearBuilt CouncilArea  \
# 1       2.0       1.0  0.0     156.0          79.0     1900.0       Yarra
# 2       3.0       2.0  0.0     134.0         150.0     1900.0       Yarra
# 4       3.0       1.0  2.0     120.0         142.0     2014.0       Yarra
# 6       4.0       2.0  0.0     245.0         210.0     1910.0       Yarra
# 7       2.0       1.0  2.0     256.0         107.0     1890.0       Yarra
#
#    Lattitude  Longtitude             Regionname  Propertycount  Year  Day  \
# ...

# %%
# Convert all categorical data to numerics
dummy_cols = ['Suburb', 'Regionname', 'CouncilArea', 'SellerG', 'Method', 'Type']
train = pd.get_dummies(melb, columns = dummy_cols)
train.head()
# check out one hot encoding
# Out:
#    Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 1      2  1035000.0       2.5    3067.0       2.0       1.0  0.0     156.0
# 2      3  1465000.0       2.5    3067.0       3.0       2.0  0.0     134.0
# 4      4  1600000.0       2.5    3067.0       3.0       1.0  2.0     120.0
# 6      3  1876000.0       2.5    3067.0       4.0       2.0  0.0     245.0
# 7      2  1636000.0       2.5    3067.0       2.0       1.0  2.0     256.0
#
#    BuildingArea  YearBuilt  Lattitude  Longtitude  Propertycount  Year  Day  \
# 1          79.0     1900.0   -37.8079    144.9934         4019.0  2016    3
# 2         150.0     1900.0   -37.8093    144.9944         4019.0  2017    5
# 4         142.0     2014.0   -37.8072    144.9941         4019.0  2016    5
# 6         210.0     1910.0   -37.8024    144.9993         4019.0  2016    5
# 7         107.0     1890.0   -37.8060    144.9954         4019.0  2016    5
#
# ...

# %%
# creating training and test sets
X = train.loc[:, train.columns != 'Price']
y = train['Price']
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.2)
print(y.head())
print(X_test.shape)
print(X_train.shape)
print(Y_train.shape)
print(Y_test.shape)
X_train
# Out:
# 1    1035000.0
# 2    1465000.0
# 4    1600000.0
# 6    1876000.0
# 7    1636000.0
# Name: Price, dtype: float64
# (1240, 552)
# (4956, 552)
# (4956,)
# (1240,)
#        Rooms  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 7380       2       9.1    3015.0       2.0       2.0  1.0     151.0
# 9898       3      16.1    3088.0       3.0       2.0  2.0    1036.0
# 3896       4      11.2    3145.0       4.0       3.0  2.0     222.0
# 7195       4      11.8    3204.0       4.0       2.0  2.0     862.0
# 9679       4      21.5    3195.0       4.0       2.0  2.0     597.0
# ...      ...       ...       ...       ...       ...  ...       ...
# 11404      3      11.7    3033.0       3.0       2.0  1.0     313.0
# 11373      2       7.3    3146.0       2.0       1.0  1.0       0.0
# 559        2       9.7    3103.0       2.0       1.0  1.0     213.0
# 2770       2       9.2    3146.0       2.0       1.0  1.0       0.0
# ...

# %%
reg= LinearRegression()
#Fit training set to the regressor
reg.fit(X_train,Y_train)

#Make predictions with the regressor
y_pred = reg.predict(X_test)

#Calculate accuracy
R2= reg.score(X_test, Y_test)
print(R2)
# Out:
# -3210398476317.4155

# %%
rf = RandomForestRegressor(random_state = 42)
#Hyperparamater tuning using RanodomSearchCV

random_grid = { 
    'n_estimators': [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [6,7,8,9,10],
    'min_samples_split' : [2, 5, 10],
    'min_samples_leaf' : [1, 2, 4]
}
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 100, cv = 5, verbose=2, random_state=42, n_jobs = -1)

# %%
rf_random.fit(X_train, Y_train)
print(rf_random.best_params_)
print(rf_random.best_score_)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   21.6s

# %%
# Transform data into DMatrix format
D_train = xgb.DMatrix(X_train, label=Y_train)
D_test = xgb.DMatrix(X_test, label=Y_test)

# %%
# set your gradient boosting ensemble parameters
param = {
    'eta': 0.3, 
    'max_depth': 3,  
    'objective': 'multi:softprob',  
    'num_class'
    } 

steps = 20  # The number of training iterations

# %%
model = xgb.train(param, D_train, steps)
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# <ipython-input-87-5288ac557fcf> in <module>
# ----> 1 model = xgb.train(param, D_train, steps)
#
# ~/miniconda3/envs/data1/lib/python3.8/site-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks)
#     206         callbacks.append(callback.record_evaluation(evals_result))
#     207
# --> 208     return _train_internal(params, dtrain,
#     209                            num_boost_round=num_boost_round,
#     210                            evals=evals,
#
# ~/miniconda3/envs/data1/lib/python3.8/site-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      73         # Skip the first update if it is a recovery step.
# ...
