# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

pd.options.display.float_format = "{:,.2f}".format
plt.figure(figsize=(80,80)) 
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('house_sales.csv')

# %%
columns_names=df.columns.tolist()
print("Columns names:")
print(columns_names)
# Out:
# Columns names:
# ['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15']

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650    1.00           0     0          3      7        1180
# 1      7242    2.00           0     0          3      7        2170
# 2     10000    1.00           0     0          3      6         770
# 3      5000    1.00           0     0          5      7        1050
# 4      8080    1.00           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode   lat    long  \
# 0              0      1955             0    98178 47.51 -122.26
# 1            400      1951          1991    98125 47.72 -122.32
# 2              0      1933             0    98028 47.74 -122.23
# 3            910      1965             0    98136 47.52 -122.39
# 4              0      1987             0    98074 47.62 -122.05
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062
# 3           1360        5000
# 4           1800        7503

# %%
df.corr()
# Out:
#                  id  price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.00  -0.02      0.00       0.01        -0.01     -0.13
# price         -0.02   1.00      0.31       0.53         0.70      0.09
# bedrooms       0.00   0.31      1.00       0.52         0.58      0.03
# bathrooms      0.01   0.53      0.52       1.00         0.75      0.09
# sqft_living   -0.01   0.70      0.58       0.75         1.00      0.17
# sqft_lot      -0.13   0.09      0.03       0.09         0.17      1.00
# floors         0.02   0.26      0.18       0.50         0.35     -0.01
# waterfront    -0.00   0.27     -0.01       0.06         0.10      0.02
# view           0.01   0.40      0.08       0.19         0.28      0.07
# condition     -0.02   0.04      0.03      -0.12        -0.06     -0.01
# grade          0.01   0.67      0.36       0.66         0.76      0.11
# sqft_above    -0.01   0.61      0.48       0.69         0.88      0.18
# sqft_basement -0.01   0.32      0.30       0.28         0.44      0.02
# yr_built       0.02   0.05      0.15       0.51         0.32      0.05
# yr_renovated  -0.02   0.13      0.02       0.05         0.06      0.01
# zipcode       -0.01  -0.05     -0.15      -0.20        -0.20     -0.13
# lat           -0.00   0.31     -0.01       0.02         0.05     -0.09
# long           0.02   0.02      0.13       0.22         0.24      0.23
# sqft_living15 -0.00   0.59      0.39       0.57         0.76      0.14
# sqft_lot15    -0.14   0.08      0.03       0.09         0.18      0.72
#
#                floors  waterfront  view  condition  grade  sqft_above  \
# id               0.02       -0.00  0.01      -0.02   0.01       -0.01
# price            0.26        0.27  0.40       0.04   0.67        0.61
# bedrooms         0.18       -0.01  0.08       0.03   0.36        0.48
# bathrooms        0.50        0.06  0.19      -0.12   0.66        0.69
# sqft_living      0.35        0.10  0.28      -0.06   0.76        0.88
# sqft_lot        -0.01        0.02  0.07      -0.01   0.11        0.18
# floors           1.00        0.02  0.03      -0.26   0.46        0.52
# waterfront       0.02        1.00  0.40       0.02   0.08        0.07
# view             0.03        0.40  1.00       0.05   0.25        0.17
# condition       -0.26        0.02  0.05       1.00  -0.14       -0.16
# grade            0.46        0.08  0.25      -0.14   1.00        0.76
# sqft_above       0.52        0.07  0.17      -0.16   0.76        1.00
# sqft_basement   -0.25        0.08  0.28       0.17   0.17       -0.05
# yr_built         0.49       -0.03 -0.05      -0.36   0.45        0.42
# yr_renovated     0.01        0.09  0.10      -0.06   0.01        0.02
# zipcode         -0.06        0.03  0.08       0.00  -0.18       -0.26
# lat              0.05       -0.01  0.01      -0.01   0.11       -0.00
# long             0.13       -0.04 -0.08      -0.11   0.20        0.34
# sqft_living15    0.28        0.09  0.28      -0.09   0.71        0.73
# sqft_lot15      -0.01        0.03  0.07      -0.00   0.12        0.19
#
#                sqft_basement  yr_built  yr_renovated  zipcode   lat  long  \
# id                     -0.01      0.02         -0.02    -0.01 -0.00  0.02
# price                   0.32      0.05          0.13    -0.05  0.31  0.02
# bedrooms                0.30      0.15          0.02    -0.15 -0.01  0.13
# bathrooms               0.28      0.51          0.05    -0.20  0.02  0.22
# sqft_living             0.44      0.32          0.06    -0.20  0.05  0.24
# sqft_lot                0.02      0.05          0.01    -0.13 -0.09  0.23
# floors                 -0.25      0.49          0.01    -0.06  0.05  0.13
# waterfront              0.08     -0.03          0.09     0.03 -0.01 -0.04
# view                    0.28     -0.05          0.10     0.08  0.01 -0.08
# condition               0.17     -0.36         -0.06     0.00 -0.01 -0.11
# grade                   0.17      0.45          0.01    -0.18  0.11  0.20
# sqft_above             -0.05      0.42          0.02    -0.26 -0.00  0.34
# sqft_basement           1.00     -0.13          0.07     0.07  0.11 -0.14
# yr_built               -0.13      1.00         -0.22    -0.35 -0.15  0.41
# yr_renovated            0.07     -0.22          1.00     0.06  0.03 -0.07
# zipcode                 0.07     -0.35          0.06     1.00  0.27 -0.56
# lat                     0.11     -0.15          0.03     0.27  1.00 -0.14
# long                   -0.14      0.41         -0.07    -0.56 -0.14  1.00
# sqft_living15           0.20      0.33         -0.00    -0.28  0.05  0.33
# sqft_lot15              0.02      0.07          0.01    -0.15 -0.09  0.25
#
#                sqft_living15  sqft_lot15
# id                     -0.00       -0.14
# price                   0.59        0.08
# bedrooms                0.39        0.03
# bathrooms               0.57        0.09
# sqft_living             0.76        0.18
# sqft_lot                0.14        0.72
# floors                  0.28       -0.01
# waterfront              0.09        0.03
# view                    0.28        0.07
# condition              -0.09       -0.00
# grade                   0.71        0.12
# sqft_above              0.73        0.19
# sqft_basement           0.20        0.02
# yr_built                0.33        0.07
# yr_renovated           -0.00        0.01
# zipcode                -0.28       -0.15
# lat                     0.05       -0.09
# long                    0.33        0.25
# sqft_living15           1.00        0.18
# sqft_lot15              0.18        1.00

# %%
correlation = df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(correlation, vmax=1, square=True,annot=True,cmap='cubehelix')

plt.title('Correlation between different fearures')
# Out:
# Text(0.5, 1.0, 'Correlation between different fearures')

# %%
df['price'].unique()
# Out:
# array([ 221900,  538000,  180000, ...,  610685, 1007500,  402101])

# %%
price=df.groupby('price').sum()
price
# Out:
#                  id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# price
# 75000    3421079032         1       0.00          670     43377    1.00
# 78000      40000362         2       1.00          780     16344    1.00
# 80000    8658300340         1       0.75          430      5050    1.00
# 81000    3028200080         2       1.00          730      9975    1.00
# 82000    3883800011         3       1.00          860     10426    1.00
# ...             ...       ...        ...          ...       ...     ...
# 5350000  8907500070         5       5.00         8000     23985    2.00
# 5570000  2470100110         5       5.75         9200     35069    2.00
# 6885000  9208900037         6       7.75         9890     31374    2.00
# 7062500  9808700762         5       4.50        10040     37325    2.00
# 7700000  6762700020         6       8.00        12050     27600    2.50
#
#          waterfront  view  condition  grade  sqft_above  sqft_basement  \
# price
# 75000             0     0          3      3         670              0
# 78000             0     0          1      5         780              0
# 80000             0     0          2      4         430              0
# 81000             0     0          1      5         730              0
# 82000             0     0          3      6         860              0
# ...             ...   ...        ...    ...         ...            ...
# 5350000           0     4          3     12        6720           1280
# 5570000           0     0          3     13        6200           3000
# 6885000           0     4          3     13        8860           1030
# 7062500           1     2          3     11        7680           2360
# 7700000           0     3          4     13        8570           3480
#
#          yr_built  yr_renovated  zipcode   lat    long  sqft_living15  \
# price
# 75000        1966             0    98022 47.26 -121.91           1160
# 78000        1942             0    98168 47.47 -122.28           1700
# 80000        1912             0    98014 47.65 -121.91           1200
# 81000        1943             0    98168 47.48 -122.31            860
# 82000        1954             0    98146 47.50 -122.34           1140
# ...           ...           ...      ...   ...     ...            ...
# 5350000      2009             0    98004 47.62 -122.22           4600
# 5570000      2001             0    98039 47.63 -122.23           3560
# 6885000      2001             0    98039 47.63 -122.24           4540
# 7062500      1940          2001    98004 47.65 -122.21           3930
# 7700000      1910          1987    98102 47.63 -122.32           3940
#
#          sqft_lot15
# price
# 75000         42882
# 78000         10387
# 80000          7500
# 81000          9000
# 82000         11250
# ...             ...
# 5350000       21750
# 5570000       24345
# 6885000       42730
# 7062500       25449
# 7700000        8800
#
# [4032 rows x 19 columns]

# %%
uniquePrice = df['price'].unique()
# Out:
# array([ 221900,  538000,  180000, ...,  610685, 1007500,  402101])

# %%
groupby_price=df.groupby('price').mean()
groupby_price
# Out:
#                       id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# price
# 75000   3,421,079,032.00      1.00       0.00       670.00 43,377.00    1.00
# 78000      40,000,362.00      2.00       1.00       780.00 16,344.00    1.00
# 80000   8,658,300,340.00      1.00       0.75       430.00  5,050.00    1.00
# 81000   3,028,200,080.00      2.00       1.00       730.00  9,975.00    1.00
# 82000   3,883,800,011.00      3.00       1.00       860.00 10,426.00    1.00
# ...                  ...       ...        ...          ...       ...     ...
# 5350000 8,907,500,070.00      5.00       5.00     8,000.00 23,985.00    2.00
# 5570000 2,470,100,110.00      5.00       5.75     9,200.00 35,069.00    2.00
# 6885000 9,208,900,037.00      6.00       7.75     9,890.00 31,374.00    2.00
# 7062500 9,808,700,762.00      5.00       4.50    10,040.00 37,325.00    2.00
# 7700000 6,762,700,020.00      6.00       8.00    12,050.00 27,600.00    2.50
#
#          waterfront  view  condition  grade  sqft_above  sqft_basement  \
# price
# 75000          0.00  0.00       3.00   3.00      670.00           0.00
# 78000          0.00  0.00       1.00   5.00      780.00           0.00
# 80000          0.00  0.00       2.00   4.00      430.00           0.00
# 81000          0.00  0.00       1.00   5.00      730.00           0.00
# 82000          0.00  0.00       3.00   6.00      860.00           0.00
# ...             ...   ...        ...    ...         ...            ...
# 5350000        0.00  4.00       3.00  12.00    6,720.00       1,280.00
# 5570000        0.00  0.00       3.00  13.00    6,200.00       3,000.00
# 6885000        0.00  4.00       3.00  13.00    8,860.00       1,030.00
# 7062500        1.00  2.00       3.00  11.00    7,680.00       2,360.00
# 7700000        0.00  3.00       4.00  13.00    8,570.00       3,480.00
#
#          yr_built  yr_renovated   zipcode   lat    long  sqft_living15  \
# price
# 75000    1,966.00          0.00 98,022.00 47.26 -121.91       1,160.00
# 78000    1,942.00          0.00 98,168.00 47.47 -122.28       1,700.00
# 80000    1,912.00          0.00 98,014.00 47.65 -121.91       1,200.00
# 81000    1,943.00          0.00 98,168.00 47.48 -122.31         860.00
# 82000    1,954.00          0.00 98,146.00 47.50 -122.34       1,140.00
# ...           ...           ...       ...   ...     ...            ...
# 5350000  2,009.00          0.00 98,004.00 47.62 -122.22       4,600.00
# 5570000  2,001.00          0.00 98,039.00 47.63 -122.23       3,560.00
# 6885000  2,001.00          0.00 98,039.00 47.63 -122.24       4,540.00
# 7062500  1,940.00      2,001.00 98,004.00 47.65 -122.21       3,930.00
# 7700000  1,910.00      1,987.00 98,102.00 47.63 -122.32       3,940.00
#
#          sqft_lot15
# price
# 75000     42,882.00
# 78000     10,387.00
# 80000      7,500.00
# 81000      9,000.00
# 82000     11,250.00
# ...             ...
# 5350000   21,750.00
# 5570000   24,345.00
# 6885000   42,730.00
# 7062500   25,449.00
# 7700000    8,800.00
#
# [4032 rows x 19 columns]

# %%
# get the features
features = ["bedrooms", "sqft_living", "sqft_lot", "floors", "waterfront", "sqft_above", "lat", "long"]
x  = df.loc[:, features].values
x
# Out:
# array([[ 3.00000e+00,  1.18000e+03,  5.65000e+03, ...,  1.18000e+03,
#          4.75112e+01, -1.22257e+02],
#        [ 3.00000e+00,  2.57000e+03,  7.24200e+03, ...,  2.17000e+03,
#          4.77210e+01, -1.22319e+02],
#        [ 2.00000e+00,  7.70000e+02,  1.00000e+04, ...,  7.70000e+02,
#          4.77379e+01, -1.22233e+02],
#        ...,
#        [ 2.00000e+00,  1.02000e+03,  1.35000e+03, ...,  1.02000e+03,
#          4.75944e+01, -1.22299e+02],
#        [ 3.00000e+00,  1.60000e+03,  2.38800e+03, ...,  1.60000e+03,
#          4.75345e+01, -1.22069e+02],
#        [ 2.00000e+00,  1.02000e+03,  1.07600e+03, ...,  1.02000e+03,
#          4.75941e+01, -1.22299e+02]])

# %%
y = df.loc[:, "price"].values
y
# Out:
# array([221900, 538000, 180000, ..., 402101, 400000, 325000])

# %%
# Standardize the features
from sklearn.preprocessing import StandardScaler
X_std = StandardScaler().fit_transform(x)
X_std
# Out:
# array([[-0.39873715, -0.97983502, -0.22832133, ..., -0.73470764,
#         -0.35257175, -0.30607896],
#        [-0.39873715,  0.53363434, -0.18988538, ...,  0.46084084,
#          1.16156823, -0.74634143],
#        [-1.47395936, -1.42625404, -0.12329847, ..., -1.22983377,
#          1.28353661, -0.13565477],
#        ...,
#        [-1.47395936, -1.15404732, -0.33213703, ..., -0.92792759,
#          0.24788796, -0.60432128],
#        [-0.39873715, -0.52252773, -0.30707641, ..., -0.22750526,
#         -0.18441416,  1.02891048],
#        [-1.47395936, -1.15404732, -0.33875227, ..., -0.92792759,
#          0.24572284, -0.60432128]])

# %% [markdown]
# # compute the eigenvectors and eigenvaluea

# %%
# Compute the covariance matrix
mean_vec = np.mean(X_std, axis=0)
cov_mat = (X_std - mean_vec).T.dot((X_std - mean_vec)) / (X_std.shape[0]-1)
print('Covariance matrix \n%s' %cov_mat)
# Out:
# Covariance matrix
# [[ 1.00004627e+00  5.76697375e-01  3.17047099e-02  1.75437052e-01
#   -6.58278324e-03  4.77622260e-01 -8.93142293e-03  1.29478966e-01]
#  [ 5.76697375e-01  1.00004627e+00  1.72833658e-01  3.53965668e-01
#    1.03822621e-01  8.76637159e-01  5.25318928e-02  2.40234413e-01]
#  [ 3.17047099e-02  1.72833658e-01  1.00004627e+00 -5.20123153e-03
#    2.16046829e-02  1.83520772e-01 -8.56867528e-02  2.29531479e-01]
#  [ 1.75437052e-01  3.53965668e-01 -5.20123153e-03  1.00004627e+00
#    2.36994168e-02  5.23908951e-01  4.96164267e-02  1.25424831e-01]
#  [-6.58278324e-03  1.03822621e-01  2.16046829e-02  2.36994168e-02
#    1.00004627e+00  7.20779266e-02 -1.42744361e-02 -4.19121393e-02]
#  [ 4.77622260e-01  8.76637159e-01  1.83520772e-01  5.23908951e-01
#    7.20779266e-02  1.00004627e+00 -8.16536350e-04  3.43818925e-01]
#  [-8.93142293e-03  5.25318928e-02 -8.56867528e-02  4.96164267e-02
#   -1.42744361e-02 -8.16536350e-04  1.00004627e+00 -1.35518054e-01]
#  [ 1.29478966e-01  2.40234413e-01  2.29531479e-01  1.25424831e-01
#   -4.19121393e-02  3.43818925e-01 -1.35518054e-01  1.00004627e+00]]

# %%
print('NumPy covariance matrix: \n%s' %np.cov(X_std.T))
# Out:
# NumPy covariance matrix:
# [[ 1.00004627e+00  5.76697375e-01  3.17047099e-02  1.75437052e-01
#   -6.58278324e-03  4.77622260e-01 -8.93142293e-03  1.29478966e-01]
#  [ 5.76697375e-01  1.00004627e+00  1.72833658e-01  3.53965668e-01
#    1.03822621e-01  8.76637159e-01  5.25318928e-02  2.40234413e-01]
#  [ 3.17047099e-02  1.72833658e-01  1.00004627e+00 -5.20123153e-03
#    2.16046829e-02  1.83520772e-01 -8.56867528e-02  2.29531479e-01]
#  [ 1.75437052e-01  3.53965668e-01 -5.20123153e-03  1.00004627e+00
#    2.36994168e-02  5.23908951e-01  4.96164267e-02  1.25424831e-01]
#  [-6.58278324e-03  1.03822621e-01  2.16046829e-02  2.36994168e-02
#    1.00004627e+00  7.20779266e-02 -1.42744361e-02 -4.19121393e-02]
#  [ 4.77622260e-01  8.76637159e-01  1.83520772e-01  5.23908951e-01
#    7.20779266e-02  1.00004627e+00 -8.16536350e-04  3.43818925e-01]
#  [-8.93142293e-03  5.25318928e-02 -8.56867528e-02  4.96164267e-02
#   -1.42744361e-02 -8.16536350e-04  1.00004627e+00 -1.35518054e-01]
#  [ 1.29478966e-01  2.40234413e-01  2.29531479e-01  1.25424831e-01
#   -4.19121393e-02  3.43818925e-01 -1.35518054e-01  1.00004627e+00]]

# %%
plt.figure(figsize=(8,8))
sns.heatmap(cov_mat, vmax=1, square=True,annot=True,cmap='cubehelix')

plt.title('Correlation between different features')
# Out:
# Text(0.5, 1.0, 'Correlation between different features')

# %%
eig_vals, eig_vecs = np.linalg.eig(cov_mat)

print('Eigenvectors \n%s' %eig_vecs)
print('\nEigenvalues \n%s' %eig_vals)
# Out:
# Eigenvectors
# [[-0.39890817 -0.08988121  0.62868866  0.14541464  0.04836819 -0.57395716
#    0.09976596  0.27327502]
#  [-0.54915615  0.66730913 -0.44673327  0.10550277 -0.02571069 -0.1981258
#   -0.04994721 -0.00387499]
#  [-0.15806351 -0.00114158  0.18157715 -0.56823528 -0.49048239 -0.17255406
#   -0.11989107 -0.57830034]
#  [-0.345398    0.16156354  0.41142729  0.23598223 -0.31674243  0.72416024
#    0.06282118  0.03093694]
#  [-0.05563008 -0.0212193   0.13093495  0.08507462  0.20386652  0.04946842
#   -0.96324109 -0.01520871]
#  [-0.5671633  -0.71588658 -0.39430643  0.04599672 -0.04045875  0.0810631
#   -0.00538947 -0.00132501]
#  [ 0.00481253 -0.03757766  0.08352316  0.56337824  0.2707232  -0.08046388
#    0.12683424 -0.76048747]
#  [-0.26499787  0.07848494  0.15277315 -0.5122464   0.73458235  0.2482813
#    0.15900407 -0.10650406]]
#
# Eigenvalues
# [2.72270369 0.08931592 0.44357055 1.23578313 0.71231095 0.86314947
#  1.01645641 0.91708006]

# %%
# Make a list of (eigenvalue, eigenvector) tuples
eig_pairs = [(np.abs(eig_vals[i]), eig_vecs[:,i]) for i in range(len(eig_vals))]

# Sort the (eigenvalue, eigenvector) tuples from high to low
eig_pairs.sort(key=lambda x: x[0], reverse=True)

# Visually confirm that the list is correctly sorted by decreasing eigenvalues
print('Eigenvalues in descending order:')
for i in eig_pairs:
    print(i[0])
# Out:
# Eigenvalues in descending order:
# 2.7227036861919416
# 1.2357831288925583
# 1.016456410496437
# 0.9170800594349228
# 0.8631494682206241
# 0.7123109475911333
# 0.4435705484794897
# 0.08931591541627189

# %%
tot = sum(eig_vals)
var_exp = [(i / tot)*100 for i in sorted(eig_vals, reverse=True)]
var_exp
# Out:
# [34.03222138642234,
#  15.446574389039997,
#  12.705117257928556,
#  11.4629703445307,
#  10.788869145412454,
#  8.90347487584985,
#  5.544375314474297,
#  1.1163972863418137]

# %%
with plt.style.context('dark_background'):
    plt.figure(figsize=(6, 4))

    plt.bar(range(8), var_exp, alpha=0.5, align='center',
            label='individual explained variance')
    plt.ylabel('Explained variance ratio')
    plt.xlabel('Principal components')
    plt.legend(loc='best')
    plt.tight_layout()

# %% [markdown]
# # PCA With Sci Kit learn

# %%
from sklearn.decomposition import PCA
pca = PCA().fit(X_std)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlim(0,7,1)
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
# Out:
# Text(0, 0.5, 'Cumulative explained variance')

# %%
from sklearn.decomposition import PCA 
sklearn_pca = PCA(n_components=3)
Y_sklearn = sklearn_pca.fit_transform(X_std)
Y_sklearn
# Out:
# array([[-1.55038   ,  0.33069553,  0.0264329 ],
#        [ 0.48059597, -1.37770994, -0.12530389],
#        [-2.45137753, -0.21784977, -0.11328377],
#        ...,
#        [-1.64323084, -0.47275851, -0.03356358],
#        [-0.03141464,  0.36645126, -0.30737184],
#        [-1.64426605, -0.47529774, -0.03408208]])

# %%
Y_sklearn.shape
# Out:
# (21613, 3)

# %% [markdown]
# # Train the model with random forest

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_std, y, test_size=0.2, random_state=1)
X_train.shape
# Out:
# (17290, 8)

# %%
# Establish model
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()

# %%
# Try different numbers of n_estimators - this will take a minute or so
estimators = np.arange(10, 200, 10)
scores = []
for n in estimators:
    model.set_params(n_estimators=n)
    model.fit(X_train, y_train)
    scores.append(model.score(X_test, y_test))
print(scores)
# Out:
# [0.5571667045583841, 0.562339065444821, 0.5680931304755185, 0.5789735259762336, 0.5743876287801375, 0.575154577813414, 0.5792839341626949, 0.5782338091300412, 0.5754734863309952, 0.5803910382701323, 0.5798653763790378, 0.5809154011968911, 0.578438639811772, 0.5788723738065673, 0.5830443430823619, 0.5768513771905508, 0.5803006060452451, 0.583355335567849, 0.582432654294478]

# %%
plt.title("Effect of n_estimators")
plt.xlabel("n_estimator")
plt.ylabel("score")
plt.plot(estimators, scores)
